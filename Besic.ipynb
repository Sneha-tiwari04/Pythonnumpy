# %%
import numpy as np

# %%
arr=np.array([1,2,3,4])
print(arr.dtype)  #datatype
print(arr.ndim)   #dimenation
# Out:
# int64
# 1

# %%
import numpy as np

# %%
arr=np.array([1,2,3,4])
print(arr.dtype)  #datatype
print(arr.ndim)   #dimenation
# Out:
# int64
# 1

# %%
arr=np.array([1,2,3,4])
print(arr.ndim)   #1dimenation

arr=np.array([
    [1,2,3,4],
    [4,5,6,7],
    ])
print(arr.ndim) #2dimenation

arr=np.array([
    [1,2,3,4],
    [4,5,6,7],
    [8,9,3,4],
    ])
print(arr.ndim)
# Out:
# 1
# 2
# 2

# %%
# Draw a scatfer 
fig, ax = plt.subplots(figsize=(8,4))
sc = ax.scatter(df['age'], df['fare'], c = df['survived'])
ax.set_title('scatter Plot ---- Age vs Fare ')
ax.set_xlabel('Age')
ax.set_ylabel('Fare (dollar)')
cbar = fig.colorbar(sc, ax = ax, ticks = [0, 1])
cbar.ax.set_yticklabels(['Died', 'Survived'])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 2
#       1 # Draw a scatfer
# ----> 2 fig, ax = plt.subplots(figsize=(8,4))
#       3 sc = ax.scatter(df['age'], df['fare'], c = df['survived'])
#       4 ax.set_title('scatter Plot ---- Age vs Fare ')
#       5 ax.set_xlabel('Age')
#
# NameError: name 'plt' is not defined
