# %%
import numpy as np 
arr= np.array([])
print(arr)
# Out:
# []

# %%
import numpy as np
import time
n=1000000

# lists
list1=list(range(n))
list2=list(range(n))

start=time.time()
result_list=[list1[i]+list2[i] for i in range(n)]
list_time=time.time()-start

arr1=np.arange(n)
arr2=np.arange(n)

start=time.time()
result_arr=arr1+arr2
numpy_time=time.time()-start

print(f"List Time :{list_time:.6f} sec")
print("Numpy Time :{Numpy_time:.6f}sec")
print(f"Numpy is approximately{list_time/numpy_time:.2f}xfaster")
# Out:
# List Time :103.455998 sec
# Numpy Time :{Numpy_time:.6f}sec
# Numpy is approximately36.20xfaster

# %%
arr=np.array([1,2])
print(arr)
# Out:
# [1 2]

# %%
arr=np.array([[1,2,3],[4,5,6]])
print(arr)
# Out:
# [[1 2 3]
#  [4 5 6]]

# %%
arr.shape
# Out:
# (2, 3)

# %%
arr.ndim
# Out:
# 2

# %%
arr.size
# Out:
# 6

# %%
arr.dtype
# Out:
# dtype('int64')

# %%
arr = np.zeros((2,3), np.int8)

# %%
arr
# Out:
# array([[0, 0, 0],
#        [0, 0, 0]], dtype=int8)

# %%
arr=np.ones((2,3),np.int8)

# %%
arr
# Out:
# array([[1, 1, 1],
#        [1, 1, 1]], dtype=int8)

# %%
arr=np.empty((2,3),np.int8)

# %%
arr
# Out:
# array([[-2, -1, -1],
#        [-1,  0,  0]], dtype=int8)

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 arr=np.arange(0,100,2),int8
#
# NameError: name 'int8' is not defined

# %%
arr=np.liuspace
