# %%
import numpy as np

# %%
import numpy as np
arr=np.array([1,3,5,7,9,3,5,9,3,5,7])
arr=np.reshape(arr(3,4))
arr
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 3
#       1 import numpy as np
#       2 arr=np.array([1,3,5,7,9,3,5,9,3,5,7])
# ----> 3 arr=np.reshape(arr(3,4))
#       4 arr
#
# TypeError: 'numpy.ndarray' object is not callable

# %%
arr=np.array([1,3,5,7,9,3,5,9,3,5,7])
arr=np.reshape(arr(3,4))
arr
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 2
#       1 arr=np.array([1,3,5,7,9,3,5,9,3,5,7])
# ----> 2 arr=np.reshape(arr(3,4))
#       3 arr
#
# TypeError: 'numpy.ndarray' object is not callable

# %%
import numpy as np
arr1=np.array([1,3,5])
arr2=np.array([4,5,7])
arr=np.concatenate((a,b),axis=None)
arr
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 4
#       1 import numpy as np
#       2 arr1=np.array([1,3,5])
#       3 arr2=np.array([4,5,7])
# ----> 4 arr=np.concatenate((a,b),axis=1)
#       5 arr
#
# NameError: name 'a' is not defined
